# %%
import importlib
import set
importlib.reload(set)
# Out:
# <module 'set' from '/Users/santiagocardenas/Documents/Projects/my_krml_25033147/src/my_krml_25033147/data/set.py'>

# %%
from set import get_open_meteo_daily_data
test_df = get_open_meteo_daily_data(
    lat = -33.8678,
	long =  151.2073,
	start_date = "2018-01-01",
	end_date = "2025-08-30",
	variables_list = ["weather_code", "temperature_2m_mean", "apparent_temperature_mean", "shortwave_radiation_sum", "et0_fao_evapotranspiration", "sunshine_duration", "daylight_duration", "precipitation_sum", "rain_sum", "precipitation_hours", "cloud_cover_mean", "dew_point_2m_mean", "relative_humidity_2m_mean", "pressure_msl_mean", "surface_pressure_mean", "wind_gusts_10m_mean", "wind_speed_10m_mean"],
	time_zone = "Australia/Sydney"
)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2799 entries, 0 to 2798
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   weather_code                2799 non-null   float32
#  1   temperature_2m_mean         2799 non-null   float32
#  2   apparent_temperature_mean   2799 non-null   float32
#  3   shortwave_radiation_sum     2799 non-null   float32
#  4   et0_fao_evapotranspiration  2799 non-null   float32
#  5   sunshine_duration           2799 non-null   float32
#  6   daylight_duration           2799 non-null   float32
#  7   precipitation_sum           2799 non-null   float32
#  8   rain_sum                    2799 non-null   float32
#  9   precipitation_hours         2799 non-null   float32
#  10  cloud_cover_mean            2799 non-null   float32
#  11  dew_point_2m_mean           2799 non-null   float32
#  12  relative_humidity_2m_mean   2799 non-null   float32
# ...

# %%
test_df['date'].nsmallest(n = 3)
# Out:
# 0   2017-12-31 14:00:00+00:00
# 1   2018-01-01 14:00:00+00:00
# 2   2018-01-02 14:00:00+00:00
# Name: date, dtype: datetime64[ns, UTC]

# %%
test_df['date'].nlargest(n = 3)
# Out:
# 2798   2025-08-29 14:00:00+00:00
# 2797   2025-08-28 14:00:00+00:00
# 2796   2025-08-27 14:00:00+00:00
# Name: date, dtype: datetime64[ns, UTC]

# %%
test_df['weather_code'].value_counts(normalize=True).sort_values(ascending=False)
# Out:
# weather_code
# 51.0    0.270096
# 3.0     0.269382
# 53.0    0.112540
# 61.0    0.077885
# 63.0    0.076813
# 2.0     0.050732
# 1.0     0.050375
# 55.0    0.039300
# 0.0     0.038228
# 65.0    0.014648
# Name: proportion, dtype: float64

# %%
importlib.reload(set)
# Out:
# <module 'set' from '/Users/santiagocardenas/Documents/Projects/my_krml_25033147/src/my_krml_25033147/data/set.py'>

# %%
test_df['rain'] = set.create_rain_column(test_df)
test_df['rain'].value_counts()
# Out:
# rain
# False    2325
# True      474
# Name: count, dtype: int64
